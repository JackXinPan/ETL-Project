# %%
# Import SQL Alchemy
from sqlalchemy import create_engine
import pandas as pd
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, inspect
from config import username, password

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
# Create a connection to a SQLite database

# engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/ETL_DB')
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/ETL')

# %%
conn = engine.connect()

# %%
total_data = pd.read_sql("SELECT * FROM total", conn)
cancer_data = pd.read_sql("SELECT * FROM cancer", conn)
cerebro_data = pd.read_sql("SELECT * FROM cerebrovascular_disease", conn)
clrd_data = pd.read_sql("SELECT * FROM chronic_lower_respiratory_disease", conn)
dementia_data = pd.read_sql("SELECT * FROM dementia", conn)
diabetes_data = pd.read_sql("SELECT * FROM diabetes", conn)
heart_data = pd.read_sql("SELECT * FROM heart_disease", conn)
pneumonia_data = pd.read_sql("SELECT * FROM pneumonia", conn)
respiratory_data = pd.read_sql("SELECT * FROM respiratory_disease", conn)

# %%
total_data['COVID-19 new infections'] = total_data['COVID-19 new infections'].fillna(0).astype(int)
total_data.head()
# Out:
#         date 2015-19 range  COVID-19 new infections  2015-19 average deaths  \
# 0  05-Jan-20     2452|2573                        0                    2498
# 1  12-Jan-20     2369|2601                        0                    2490
# 2  19-Jan-20     2368|2607                        0                    2465
# 3  26-Jan-20     2328|2565                        4                    2446
# 4  02-Feb-20     2270|2550                        8                    2451
#
#    2020-21 deaths
# 0            2498
# 1            2511
# 2            2501
# 3            2597
# 4            2510

# %%
# dropping redundant columns
new_total_data = total_data.drop(['COVID-19 new infections'], axis=1)

#cleaning total_data table
#adding new columns of total and percent change
new_total_data['total change'] = new_total_data['2020-21 deaths'] - new_total_data['2015-19 average deaths']
new_total_data['percent total change'] = (new_total_data['2020-21 deaths'] / new_total_data['2015-19 average deaths']) * 100 - 100
new_total_data = new_total_data.round(2)

#renaming columns for future joins
new_total_data = new_total_data.rename({'2015-19 average deaths': '2015-19 avg total deaths',
                               '2020-21 deaths': '2020-21 total deaths'}, axis=1)

new_total_data.head()
# Out:
#         date 2015-19 range  2015-19 avg total deaths  2020-21 total deaths  \
# 0  05-Jan-20     2452|2573                      2498                  2498
# 1  12-Jan-20     2369|2601                      2490                  2511
# 2  19-Jan-20     2368|2607                      2465                  2501
# 3  26-Jan-20     2328|2565                      2446                  2597
# 4  02-Feb-20     2270|2550                      2451                  2510
#
#    total change  percent total change
# 0             0                  0.00
# 1            21                  0.84
# 2            36                  1.46
# 3           151                  6.17
# 4            59                  2.41

# %%
print(new_total_data["2015-19 avg total deaths"].mean())
print(new_total_data["2020-21 total deaths"].mean())
# Out:
# 2668.4262295081967
# 2685.032786885246

# %%
#cleaning total_data table
#adding new columns of total and percent change
cancer_data['total change'] = cancer_data['2020-21 deaths'] - cancer_data['2015-19 average deaths']
cancer_data['percent total change'] = (cancer_data['2020-21 deaths'] / cancer_data['2015-19 average deaths']) * 100 - 100
cancer_data = cancer_data.round(2)

#renaming columns for future joins
cancer_data = cancer_data.rename({'2015-19 average deaths': '2015-19 avg cancer deaths',
                               '2020-21 deaths': '2020-21 cancer deaths'}, axis=1)

cancer_data.head()
# Out:
#         date 2015-19 range  2015-19 avg cancer deaths  2020-21 cancer deaths  \
# 0  05-Jan-20       847|906                        868                    849
# 1  12-Jan-20       817|917                        869                    899
# 2  19-Jan-20       853|915                        874                    912
# 3  26-Jan-20       806|942                        870                    931
# 4  02-Feb-20       762|933                        864                    830
#
#    total change  percent total change
# 0           -19                 -2.19
# 1            30                  3.45
# 2            38                  4.35
# 3            61                  7.01
# 4           -34                 -3.94

# %%
#cleaning total_data table
#adding new columns of total and percent change
cerebro_data['total change'] = cerebro_data['2020-21 deaths'] - cerebro_data['2015-19 average deaths']
cerebro_data['percent total change'] = (cerebro_data['2020-21 deaths'] / cerebro_data['2015-19 average deaths']) * 100 - 100
cerebro_data = cerebro_data.round(2)

#renaming columns for future joins
cerebro_data = cerebro_data.rename({'2015-19 average deaths': '2015-19 cerebrovascular disease deaths',
                               '2020-21 deaths': '2020-21 cerebrovascular disease deaths'}, axis=1)

cerebro_data.head()
# Out:
#         date 2015-19 range  2015-19 cerebrovascular disease deaths  \
# 0  05-Jan-20       159|200                                     182
# 1  12-Jan-20       162|190                                     178
# 2  19-Jan-20       144|179                                     167
# 3  26-Jan-20       165|203                                     176
# 4  02-Feb-20       156|175                                     168
#
#    2020-21 cerebrovascular disease deaths  total change  percent total change
# 0                                     139           -43                -23.63
# 1                                     166           -12                 -6.74
# 2                                     141           -26                -15.57
# 3                                     159           -17                 -9.66
# 4                                     162            -6                 -3.57

# %%
#cleaning total_data table
#adding new columns of total and percent change
clrd_data['total change'] = clrd_data['2020-21 deaths'] - clrd_data['2015-19 average deaths']
clrd_data['percent total change'] = (clrd_data['2020-21 deaths'] / clrd_data['2015-19 average deaths']) * 100 - 100
clrd_data = clrd_data.round(2)

#renaming columns for future joins
clrd_data = clrd_data.rename({'2015-19 average deaths': '2015-19 avg chronic lower respiratory disease deaths',
                               '2020-21 deaths': '2020-21 chronic lower respiratory disease deaths'}, axis=1)

clrd_data.head()
# Out:
#         date 2015-19 range  \
# 0  05-Jan-20       117|157
# 1  12-Jan-20       110|144
# 2  19-Jan-20       104|138
# 3  26-Jan-20       113|141
# 4  02-Feb-20       114|134
#
#    2015-19 avg chronic lower respiratory disease deaths  \
# 0                                                133
# 1                                                124
# 2                                                118
# 3                                                126
# 4                                                125
#
#    2020-21 chronic lower respiratory disease deaths  total change  \
# 0                                               127            -6
# 1                                               145            21
# 2                                               120             2
# 3                                               132             6
# 4                                               134             9
#
#    percent total change
# 0                 -4.51
# 1                 16.94
# 2                  1.69
# 3                  4.76
# 4                  7.20

# %%
#cleaning total_data table
#adding new columns of total and percent change
dementia_data['total change'] = dementia_data['2020-21 deaths'] - dementia_data['2015-19 average deaths']
dementia_data['percent total change'] = (dementia_data['2020-21 deaths'] / dementia_data['2015-19 average deaths']) * 100 - 100
dementia_data = dementia_data.round(2)

#renaming columns for future joins
dementia_data = dementia_data.rename({'2015-19 average deaths': '2015-19 avg dementia deaths',
                               '2020-21 deaths': '2020-21 dementia deaths'}, axis=1)

dementia_data.head()
# Out:
#         date 2015-19 range  2015-19 avg dementia deaths  \
# 0  05-Jan-20       217|256                          232
# 1  12-Jan-20       208|240                          224
# 2  19-Jan-20       206|237                          220
# 3  26-Jan-20       186|247                          218
# 4  02-Feb-20       196|234                          220
#
#    2020-21 dementia deaths  total change  percent total change
# 0                      255            23                  9.91
# 1                      265            41                 18.30
# 2                      257            37                 16.82
# 3                      248            30                 13.76
# 4                      276            56                 25.45

# %%
#cleaning total_data table
#adding new columns of total and percent change
diabetes_data['total change'] = diabetes_data['2020-21 deaths'] - diabetes_data['2015-19 average deaths']
diabetes_data['percent total change'] = (diabetes_data['2020-21 deaths'] / diabetes_data['2015-19 average deaths']) * 100 - 100
diabetes_data = diabetes_data.round(2)

#renaming columns for future joins
diabetes_data = diabetes_data.rename({'2015-19 average deaths': '2015-19 avg diabetes deaths',
                               '2020-21 deaths': '2020-21 diabetes deaths'}, axis=1)

diabetes_data.head()
# Out:
#         date 2015-19 range  2015-19 avg diabetes deaths  \
# 0  05-Jan-20         66|78                           71
# 1  12-Jan-20         69|79                           74
# 2  19-Jan-20         74|97                           83
# 3  26-Jan-20         62|99                           80
# 4  02-Feb-20         63|88                           78
#
#    2020-21 diabetes deaths  total change  percent total change
# 0                       86            15                 21.13
# 1                       71            -3                 -4.05
# 2                       71           -12                -14.46
# 3                       77            -3                 -3.75
# 4                       80             2                  2.56

# %%
#cleaning total_data table
#adding new columns of total and percent change
heart_data['total change'] = heart_data['2020-21 deaths'] - heart_data['2015-19 average deaths']
heart_data['percent total change'] = (heart_data['2020-21 deaths'] / heart_data['2015-19 average deaths']) * 100 - 100
heart_data = heart_data.round(2)

#renaming columns for future joins
heart_data = heart_data.rename({'2015-19 average deaths': '2015-19 avg heart disease deaths',
                               '2020-21 deaths': '2020-21 heart disease deaths'}, axis=1)

heart_data.head()
# Out:
#         date 2015-19 range  2015-19 avg heart disease deaths  \
# 0  05-Jan-20       245|291                               269
# 1  12-Jan-20       246|272                               258
# 2  19-Jan-20       244|304                               272
# 3  26-Jan-20       210|271                               245
# 4  02-Feb-20       257|276                               267
#
#    2020-21 heart disease deaths  total change  percent total change
# 0                           215           -54                -20.07
# 1                           218           -40                -15.50
# 2                           234           -38                -13.97
# 3                           244            -1                 -0.41
# 4                           235           -32                -11.99

# %%
#cleaning total_data table
#adding new columns of total and percent change
pneumonia_data['total change'] = pneumonia_data['2020-21 deaths'] - pneumonia_data['2015-19 average deaths']
pneumonia_data['percent total change'] = (pneumonia_data['2020-21 deaths'] / pneumonia_data['2015-19 average deaths']) * 100 - 100
pneumonia_data = pneumonia_data.round(2)

#renaming columns for future joins
pneumonia_data = pneumonia_data.rename({'2015-19 average deaths': '2015-19 avg pneumonia deaths',
                               '2020-21 deaths': '2020-21 pneumonia deaths'}, axis=1)

pneumonia_data.head()
# Out:
#         date 2015-19 range  2015-19 avg pneumonia deaths  \
# 0  05-Jan-20         37|58                            45
# 1  12-Jan-20         37|49                            42
# 2  19-Jan-20         33|44                            37
# 3  26-Jan-20         29|40                            35
# 4  02-Feb-20         31|50                            37
#
#    2020-21 pneumonia deaths  total change  percent total change
# 0                        42            -3                 -6.67
# 1                        40            -2                 -4.76
# 2                        37             0                  0.00
# 3                        44             9                 25.71
# 4                        31            -6                -16.22

# %%
#cleaning total_data table
#adding new columns of total and percent change
respiratory_data['total change'] = respiratory_data['2020-21 deaths'] - respiratory_data['2015-19 average deaths']
respiratory_data['percent total change'] = (respiratory_data['2020-21 deaths'] / respiratory_data['2015-19 average deaths']) * 100 - 100
respiratory_data = respiratory_data.round(2)

#renaming columns for future joins
respiratory_data = respiratory_data.rename({'2015-19 average deaths': '2015-19 avg respiratory disease deaths',
                              '2020-21 deaths': '2020-21 respiratory disease deaths'}, axis=1)

respiratory_data.head()
# Out:
#         date 2015-19 range  2015-19 avg respiratory disease deaths  \
# 0  05-Jan-20       215|263                                     233
# 1  12-Jan-20       203|251                                     220
# 2  19-Jan-20       193|233                                     206
# 3  26-Jan-20       197|242                                     218
# 4  02-Feb-20       200|229                                     219
#
#    2020-21 respiratory disease deaths  total change  percent total change
# 0                                 240             7                  3.00
# 1                                 240            20                  9.09
# 2                                 222            16                  7.77
# 3                                 242            24                 11.01
# 4                                 226             7                  3.20

# %%
data = [total_data["date"],
        new_total_data["2015-19 avg total deaths"],
        cancer_data["2015-19 avg cancer deaths"],
        cerebro_data["2015-19 cerebrovascular disease deaths"], 
        clrd_data["2015-19 avg chronic lower respiratory disease deaths"], 
        dementia_data["2015-19 avg dementia deaths"],
        diabetes_data["2015-19 avg diabetes deaths"],
        heart_data["2015-19 avg heart disease deaths"],
        pneumonia_data["2015-19 avg pneumonia deaths"],
        respiratory_data["2015-19 avg respiratory disease deaths"]]
Deaths_Summary2015_19 = pd.DataFrame(data)
print(Deaths_Summary2015_19)
# Out:
#                                                            0          1   \
# date                                                05-Jan-20  12-Jan-20
# 2015-19 avg total deaths                                 2498       2490
# 2015-19 avg cancer deaths                                 868        869
# 2015-19 cerebrovascular disease deaths                    182        178
# 2015-19 avg chronic lower respiratory disease d...        133        124
# 2015-19 avg dementia deaths                               232        224
# 2015-19 avg diabetes deaths                                71         74
# 2015-19 avg heart disease deaths                          269        258
# 2015-19 avg pneumonia deaths                               45         42
# 2015-19 avg respiratory disease deaths                    233        220
#
#                                                            2          3   \
# date                                                19-Jan-20  26-Jan-20
# 2015-19 avg total deaths                                 2465       2446
# 2015-19 avg cancer deaths                                 874        870
# 2015-19 cerebrovascular disease deaths                    167        176
# 2015-19 avg chronic lower respiratory disease d...        118        126
# 2015-19 avg dementia deaths                               220        218
# 2015-19 avg diabetes deaths                                83         80
# 2015-19 avg heart disease deaths                          272        245
# 2015-19 avg pneumonia deaths                               37         35
# 2015-19 avg respiratory disease deaths                    206        218
#
#                                                            4          5   \
# date                                                02-Feb-20  09-Feb-20
# 2015-19 avg total deaths                                 2451       2456
# 2015-19 avg cancer deaths                                 864        858
# 2015-19 cerebrovascular disease deaths                    168        165
# 2015-19 avg chronic lower respiratory disease d...        125        119
# 2015-19 avg dementia deaths                               220        224
# 2015-19 avg diabetes deaths                                78         85
# 2015-19 avg heart disease deaths                          267        265
# 2015-19 avg pneumonia deaths                               37         35
# 2015-19 avg respiratory disease deaths                    219        212
#
#                                                            6          7   \
# date                                                16-Feb-20  23-Feb-20
# 2015-19 avg total deaths                                 2463       2488
# 2015-19 avg cancer deaths                                 858        892
# 2015-19 cerebrovascular disease deaths                    170        175
# 2015-19 avg chronic lower respiratory disease d...        118        109
# 2015-19 avg dementia deaths                               226        226
# 2015-19 avg diabetes deaths                                75         77
# 2015-19 avg heart disease deaths                          250        255
# 2015-19 avg pneumonia deaths                               43         40
# 2015-19 avg respiratory disease deaths                    216        206
#
#                                                            8          9   ...  \
# date                                                01-Mar-20  08-Mar-20  ...
# 2015-19 avg total deaths                                 2487       2525  ...
# 2015-19 avg cancer deaths                                 906        906  ...
# 2015-19 cerebrovascular disease deaths                    165        173  ...
# 2015-19 avg chronic lower respiratory disease d...        113        120  ...
# 2015-19 avg dementia deaths                               225        230  ...
# 2015-19 avg diabetes deaths                                79         75  ...
# 2015-19 avg heart disease deaths                          260        261  ...
# 2015-19 avg pneumonia deaths                               40         36  ...
# 2015-19 avg respiratory disease deaths                    213        213  ...
#
#                                                            51         52  \
# date                                                27-Dec-20  03-Jan-21
# 2015-19 avg total deaths                                 2458       2458
# 2015-19 avg cancer deaths                                 858        858
# 2015-19 cerebrovascular disease deaths                    168        168
# 2015-19 avg chronic lower respiratory disease d...        125        125
# 2015-19 avg dementia deaths                               234        234
# 2015-19 avg diabetes deaths                                82         82
# 2015-19 avg heart disease deaths                          240        240
# 2015-19 avg pneumonia deaths                               42         42
# 2015-19 avg respiratory disease deaths                    227        227
#
#                                                            53         54  \
# date                                                10-Jan-21  17-Jan-21
# 2015-19 avg total deaths                                 2498       2490
# 2015-19 avg cancer deaths                                 868        869
# 2015-19 cerebrovascular disease deaths                    182        178
# 2015-19 avg chronic lower respiratory disease d...        133        124
# 2015-19 avg dementia deaths                               232        224
# 2015-19 avg diabetes deaths                                71         74
# 2015-19 avg heart disease deaths                          269        258
# 2015-19 avg pneumonia deaths                               45         42
# 2015-19 avg respiratory disease deaths                    233        220
#
#                                                            55         56  \
# date                                                24-Jan-21  31-Jan-21
# 2015-19 avg total deaths                                 2465       2446
# 2015-19 avg cancer deaths                                 874        870
# 2015-19 cerebrovascular disease deaths                    167        176
# 2015-19 avg chronic lower respiratory disease d...        118        126
# 2015-19 avg dementia deaths                               220        218
# 2015-19 avg diabetes deaths                                83         80
# 2015-19 avg heart disease deaths                          272        245
# 2015-19 avg pneumonia deaths                               37         35
# 2015-19 avg respiratory disease deaths                    206        218
#
#                                                            57         58  \
# date                                                07-Feb-21  14-Feb-21
# 2015-19 avg total deaths                                 2451       2456
# 2015-19 avg cancer deaths                                 864        858
# 2015-19 cerebrovascular disease deaths                    168        165
# 2015-19 avg chronic lower respiratory disease d...        125        119
# 2015-19 avg dementia deaths                               220        224
# 2015-19 avg diabetes deaths                                78         85
# 2015-19 avg heart disease deaths                          267        265
# 2015-19 avg pneumonia deaths                               37         35
# 2015-19 avg respiratory disease deaths                    219        212
#
#                                                            59         60
# date                                                21-Feb-21  28-Feb-21
# 2015-19 avg total deaths                                 2463       2488
# 2015-19 avg cancer deaths                                 858        892
# 2015-19 cerebrovascular disease deaths                    170        175
# 2015-19 avg chronic lower respiratory disease d...        118        109
# 2015-19 avg dementia deaths                               226        226
# 2015-19 avg diabetes deaths                                75         77
# 2015-19 avg heart disease deaths                          250        255
# 2015-19 avg pneumonia deaths                               43         40
# 2015-19 avg respiratory disease deaths                    216        206
#
# [10 rows x 61 columns]

# %%
Deaths_Summary2015_19 = Deaths_Summary2015_19.T
Deaths_Summary2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg cancer deaths  \
# 0   05-Jan-20                     2498                       868
# 1   12-Jan-20                     2490                       869
# 2   19-Jan-20                     2465                       874
# 3   26-Jan-20                     2446                       870
# 4   02-Feb-20                     2451                       864
# ..        ...                      ...                       ...
# 56  31-Jan-21                     2446                       870
# 57  07-Feb-21                     2451                       864
# 58  14-Feb-21                     2456                       858
# 59  21-Feb-21                     2463                       858
# 60  28-Feb-21                     2488                       892
#
#    2015-19 cerebrovascular disease deaths  \
# 0                                     182
# 1                                     178
# 2                                     167
# 3                                     176
# 4                                     168
# ..                                    ...
# 56                                    176
# 57                                    168
# 58                                    165
# 59                                    170
# 60                                    175
#
#    2015-19 avg chronic lower respiratory disease deaths  \
# 0                                                 133
# 1                                                 124
# 2                                                 118
# 3                                                 126
# 4                                                 125
# ..                                                ...
# 56                                                126
# 57                                                125
# 58                                                119
# 59                                                118
# 60                                                109
#
#    2015-19 avg dementia deaths 2015-19 avg diabetes deaths  \
# 0                          232                          71
# 1                          224                          74
# 2                          220                          83
# 3                          218                          80
# 4                          220                          78
# ..                         ...                         ...
# 56                         218                          80
# 57                         220                          78
# 58                         224                          85
# 59                         226                          75
# 60                         226                          77
#
#    2015-19 avg heart disease deaths 2015-19 avg pneumonia deaths  \
# 0                               269                           45
# 1                               258                           42
# 2                               272                           37
# 3                               245                           35
# 4                               267                           37
# ..                              ...                          ...
# 56                              245                           35
# 57                              267                           37
# 58                              265                           35
# 59                              250                           43
# 60                              255                           40
#
#    2015-19 avg respiratory disease deaths
# 0                                     233
# 1                                     220
# 2                                     206
# 3                                     218
# 4                                     219
# ..                                    ...
# 56                                    218
# 57                                    219
# 58                                    212
# 59                                    216
# 60                                    206
#
# [61 rows x 10 columns]

# %%
data = [total_data["date"],
            total_data["COVID-19 new infections"], 
            new_total_data["2020-21 total deaths"],
            cancer_data["2020-21 cancer deaths"],
            cerebro_data["2020-21 cerebrovascular disease deaths"],
            clrd_data["2020-21 chronic lower respiratory disease deaths"],
            dementia_data["2020-21 dementia deaths"],
            diabetes_data["2020-21 diabetes deaths"],
            heart_data["2020-21 heart disease deaths"], 
            pneumonia_data["2020-21 pneumonia deaths"], 
            respiratory_data["2020-21 respiratory disease deaths"], 
            ]
Deaths_Summary2020_21 = pd.DataFrame(data)
Deaths_Summary2020_21
# Out:
#                                                          0          1   \
# date                                              05-Jan-20  12-Jan-20
# COVID-19 new infections                                   0          0
# 2020-21 total deaths                                   2498       2511
# 2020-21 cancer deaths                                   849        899
# 2020-21 cerebrovascular disease deaths                  139        166
# 2020-21 chronic lower respiratory disease deaths        127        145
# 2020-21 dementia deaths                                 255        265
# 2020-21 diabetes deaths                                  86         71
# 2020-21 heart disease deaths                            215        218
# 2020-21 pneumonia deaths                                 42         40
# 2020-21 respiratory disease deaths                      240        240
#
#                                                          2          3   \
# date                                              19-Jan-20  26-Jan-20
# COVID-19 new infections                                   0          4
# 2020-21 total deaths                                   2501       2597
# 2020-21 cancer deaths                                   912        931
# 2020-21 cerebrovascular disease deaths                  141        159
# 2020-21 chronic lower respiratory disease deaths        120        132
# 2020-21 dementia deaths                                 257        248
# 2020-21 diabetes deaths                                  71         77
# 2020-21 heart disease deaths                            234        244
# 2020-21 pneumonia deaths                                 37         44
# 2020-21 respiratory disease deaths                      222        242
#
#                                                          4          5   \
# date                                              02-Feb-20  09-Feb-20
# COVID-19 new infections                                   8          3
# 2020-21 total deaths                                   2510       2530
# 2020-21 cancer deaths                                   830        927
# 2020-21 cerebrovascular disease deaths                  162        165
# 2020-21 chronic lower respiratory disease deaths        134        111
# 2020-21 dementia deaths                                 276        279
# 2020-21 diabetes deaths                                  80         93
# 2020-21 heart disease deaths                            235        207
# 2020-21 pneumonia deaths                                 31         41
# 2020-21 respiratory disease deaths                      226        206
#
#                                                          6          7   \
# date                                              16-Feb-20  23-Feb-20
# COVID-19 new infections                                   0          7
# 2020-21 total deaths                                   2613       2608
# 2020-21 cancer deaths                                   935        939
# 2020-21 cerebrovascular disease deaths                  164        147
# 2020-21 chronic lower respiratory disease deaths        128        130
# 2020-21 dementia deaths                                 256        266
# 2020-21 diabetes deaths                                  79         97
# 2020-21 heart disease deaths                            262        262
# 2020-21 pneumonia deaths                                 39         42
# 2020-21 respiratory disease deaths                      226        220
#
#                                                          8          9   ...  \
# date                                              01-Mar-20  08-Mar-20  ...
# COVID-19 new infections                                   4         53  ...
# 2020-21 total deaths                                   2678       2602  ...
# 2020-21 cancer deaths                                   956        888  ...
# 2020-21 cerebrovascular disease deaths                  158        156  ...
# 2020-21 chronic lower respiratory disease deaths        143        134  ...
# 2020-21 dementia deaths                                 288        272  ...
# 2020-21 diabetes deaths                                  91         77  ...
# 2020-21 heart disease deaths                            227        240  ...
# 2020-21 pneumonia deaths                                 52         38  ...
# 2020-21 respiratory disease deaths                      265        231  ...
#
#                                                          51         52  \
# date                                              27-Dec-20  03-Jan-21
# COVID-19 new infections                                 136        170
# 2020-21 total deaths                                   2636       2560
# 2020-21 cancer deaths                                   927        900
# 2020-21 cerebrovascular disease deaths                  154        179
# 2020-21 chronic lower respiratory disease deaths        117        136
# 2020-21 dementia deaths                                 257        278
# 2020-21 diabetes deaths                                 108        101
# 2020-21 heart disease deaths                            233        245
# 2020-21 pneumonia deaths                                 36         31
# 2020-21 respiratory disease deaths                      222        241
#
#                                                          53         54  \
# date                                              10-Jan-21  17-Jan-21
# COVID-19 new infections                                 108        111
# 2020-21 total deaths                                   2595       2515
# 2020-21 cancer deaths                                   922        897
# 2020-21 cerebrovascular disease deaths                  172        149
# 2020-21 chronic lower respiratory disease deaths        139        113
# 2020-21 dementia deaths                                 253        255
# 2020-21 diabetes deaths                                  84         64
# 2020-21 heart disease deaths                            230        223
# 2020-21 pneumonia deaths                                 27         29
# 2020-21 respiratory disease deaths                      221        210
#
#                                                          55         56  \
# date                                              24-Jan-21  31-Jan-21
# COVID-19 new infections                                  59         44
# 2020-21 total deaths                                   2679       2527
# 2020-21 cancer deaths                                   917        894
# 2020-21 cerebrovascular disease deaths                  166        156
# 2020-21 chronic lower respiratory disease deaths        131        113
# 2020-21 dementia deaths                                 311        289
# 2020-21 diabetes deaths                                  76         61
# 2020-21 heart disease deaths                            248        221
# 2020-21 pneumonia deaths                                 34         26
# 2020-21 respiratory disease deaths                      224        211
#
#                                                          57         58  \
# date                                              07-Feb-21  14-Feb-21
# COVID-19 new infections                                  39         46
# 2020-21 total deaths                                   2650       2534
# 2020-21 cancer deaths                                   926        914
# 2020-21 cerebrovascular disease deaths                  165        159
# 2020-21 chronic lower respiratory disease deaths        127        107
# 2020-21 dementia deaths                                 261        240
# 2020-21 diabetes deaths                                  83         78
# 2020-21 heart disease deaths                            249        250
# 2020-21 pneumonia deaths                                 37         27
# 2020-21 respiratory disease deaths                      231        199
#
#                                                          59         60
# date                                              21-Feb-21  28-Feb-21
# COVID-19 new infections                                  25         42
# 2020-21 total deaths                                   2512       2623
# 2020-21 cancer deaths                                   907        948
# 2020-21 cerebrovascular disease deaths                  174        164
# 2020-21 chronic lower respiratory disease deaths        110        126
# 2020-21 dementia deaths                                 257        266
# 2020-21 diabetes deaths                                  74         60
# 2020-21 heart disease deaths                            208        244
# 2020-21 pneumonia deaths                                 37         37
# 2020-21 respiratory disease deaths                      197        226
#
# [11 rows x 61 columns]

# %%
Deaths_Summary2020_21 = Deaths_Summary2020_21.T
Deaths_Summary2020_21
# Out:
#          date COVID-19 new infections 2020-21 total deaths  \
# 0   05-Jan-20                       0                 2498
# 1   12-Jan-20                       0                 2511
# 2   19-Jan-20                       0                 2501
# 3   26-Jan-20                       4                 2597
# 4   02-Feb-20                       8                 2510
# ..        ...                     ...                  ...
# 56  31-Jan-21                      44                 2527
# 57  07-Feb-21                      39                 2650
# 58  14-Feb-21                      46                 2534
# 59  21-Feb-21                      25                 2512
# 60  28-Feb-21                      42                 2623
#
#    2020-21 cancer deaths 2020-21 cerebrovascular disease deaths  \
# 0                    849                                    139
# 1                    899                                    166
# 2                    912                                    141
# 3                    931                                    159
# 4                    830                                    162
# ..                   ...                                    ...
# 56                   894                                    156
# 57                   926                                    165
# 58                   914                                    159
# 59                   907                                    174
# 60                   948                                    164
#
#    2020-21 chronic lower respiratory disease deaths 2020-21 dementia deaths  \
# 0                                               127                     255
# 1                                               145                     265
# 2                                               120                     257
# 3                                               132                     248
# 4                                               134                     276
# ..                                              ...                     ...
# 56                                              113                     289
# 57                                              127                     261
# 58                                              107                     240
# 59                                              110                     257
# 60                                              126                     266
#
#    2020-21 diabetes deaths 2020-21 heart disease deaths  \
# 0                       86                          215
# 1                       71                          218
# 2                       71                          234
# 3                       77                          244
# 4                       80                          235
# ..                     ...                          ...
# 56                      61                          221
# 57                      83                          249
# 58                      78                          250
# 59                      74                          208
# 60                      60                          244
#
#    2020-21 pneumonia deaths 2020-21 respiratory disease deaths
# 0                        42                                240
# 1                        40                                240
# 2                        37                                222
# 3                        44                                242
# 4                        31                                226
# ..                      ...                                ...
# 56                       26                                211
# 57                       37                                231
# 58                       27                                199
# 59                       37                                197
# 60                       37                                226
#
# [61 rows x 11 columns]

# %%
data = [cancer_data['date'], new_total_data['2015-19 avg total deaths'], cancer_data['2015-19 avg cancer deaths']]
cancer_data_2015_19 = pd.DataFrame(data)
cancer_data_2015_19 = cancer_data_2015_19.T
cancer_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg cancer deaths
# 0   05-Jan-20                     2498                       868
# 1   12-Jan-20                     2490                       869
# 2   19-Jan-20                     2465                       874
# 3   26-Jan-20                     2446                       870
# 4   02-Feb-20                     2451                       864
# ..        ...                      ...                       ...
# 56  31-Jan-21                     2446                       870
# 57  07-Feb-21                     2451                       864
# 58  14-Feb-21                     2456                       858
# 59  21-Feb-21                     2463                       858
# 60  28-Feb-21                     2488                       892
#
# [61 rows x 3 columns]

# %%
cancer_data_2015_19['2015-19 Cancer Percentage of Total Deaths'] = (cancer_data_2015_19['2015-19 avg cancer deaths'] / cancer_data_2015_19['2015-19 avg total deaths']) * 100

cancer_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg cancer deaths  \
# 0   05-Jan-20                     2498                       868
# 1   12-Jan-20                     2490                       869
# 2   19-Jan-20                     2465                       874
# 3   26-Jan-20                     2446                       870
# 4   02-Feb-20                     2451                       864
# ..        ...                      ...                       ...
# 56  31-Jan-21                     2446                       870
# 57  07-Feb-21                     2451                       864
# 58  14-Feb-21                     2456                       858
# 59  21-Feb-21                     2463                       858
# 60  28-Feb-21                     2488                       892
#
#    2015-19 Cancer Percentage of Total Deaths
# 0                                    34.7478
# 1                                    34.8996
# 2                                    35.4564
# 3                                    35.5683
# 4                                    35.2509
# ..                                       ...
# 56                                   35.5683
# 57                                   35.2509
# 58                                   34.9349
# 59                                   34.8356
# 60                                   35.8521
#
# [61 rows x 4 columns]

# %%
data = [cancer_data['date'], new_total_data['2020-21 total deaths'], cancer_data['2020-21 cancer deaths']]
cancer_data_2020_21 = pd.DataFrame(data)
cancer_data_2020_21 = cancer_data_2020_21.T
cancer_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 cancer deaths
# 0   05-Jan-20                 2498                   849
# 1   12-Jan-20                 2511                   899
# 2   19-Jan-20                 2501                   912
# 3   26-Jan-20                 2597                   931
# 4   02-Feb-20                 2510                   830
# ..        ...                  ...                   ...
# 56  31-Jan-21                 2527                   894
# 57  07-Feb-21                 2650                   926
# 58  14-Feb-21                 2534                   914
# 59  21-Feb-21                 2512                   907
# 60  28-Feb-21                 2623                   948
#
# [61 rows x 3 columns]

# %%
cancer_data_2020_21['2020-21 Cancer Percentage of Total Deaths'] = (cancer_data_2020_21['2020-21 cancer deaths'] / cancer_data_2020_21['2020-21 total deaths']) * 100
cancer_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 cancer deaths  \
# 0   05-Jan-20                 2498                   849
# 1   12-Jan-20                 2511                   899
# 2   19-Jan-20                 2501                   912
# 3   26-Jan-20                 2597                   931
# 4   02-Feb-20                 2510                   830
# ..        ...                  ...                   ...
# 56  31-Jan-21                 2527                   894
# 57  07-Feb-21                 2650                   926
# 58  14-Feb-21                 2534                   914
# 59  21-Feb-21                 2512                   907
# 60  28-Feb-21                 2623                   948
#
#    2020-21 Cancer Percentage of Total Deaths
# 0                                    33.9872
# 1                                    35.8025
# 2                                    36.4654
# 3                                    35.8491
# 4                                    33.0677
# ..                                       ...
# 56                                   35.3779
# 57                                   34.9434
# 58                                   36.0695
# 59                                   36.1067
# 60                                   36.1418
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], cerebro_data['2015-19 cerebrovascular disease deaths']]
cerebro_data_2015_19 = pd.DataFrame(data)
cerebro_data_2015_19 = cerebro_data_2015_19.T
cerebro_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 cerebrovascular disease deaths
# 0   05-Jan-20                     2498                                    182
# 1   12-Jan-20                     2490                                    178
# 2   19-Jan-20                     2465                                    167
# 3   26-Jan-20                     2446                                    176
# 4   02-Feb-20                     2451                                    168
# ..        ...                      ...                                    ...
# 56  31-Jan-21                     2446                                    176
# 57  07-Feb-21                     2451                                    168
# 58  14-Feb-21                     2456                                    165
# 59  21-Feb-21                     2463                                    170
# 60  28-Feb-21                     2488                                    175
#
# [61 rows x 3 columns]

# %%
cerebro_data_2015_19['2015-19 cerebrovascular disease Percentage of Total Deaths'] = (cerebro_data_2015_19['2015-19 cerebrovascular disease deaths'] / cerebro_data_2015_19['2015-19 avg total deaths']) * 100
cerebro_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 cerebrovascular disease deaths  \
# 0   05-Jan-20                     2498                                    182
# 1   12-Jan-20                     2490                                    178
# 2   19-Jan-20                     2465                                    167
# 3   26-Jan-20                     2446                                    176
# 4   02-Feb-20                     2451                                    168
# ..        ...                      ...                                    ...
# 56  31-Jan-21                     2446                                    176
# 57  07-Feb-21                     2451                                    168
# 58  14-Feb-21                     2456                                    165
# 59  21-Feb-21                     2463                                    170
# 60  28-Feb-21                     2488                                    175
#
#    2015-19 cerebrovascular disease Percentage of Total Deaths
# 0                                             7.28583
# 1                                             7.14859
# 2                                             6.77485
# 3                                             7.19542
# 4                                             6.85435
# ..                                                ...
# 56                                            7.19542
# 57                                            6.85435
# 58                                            6.71824
# 59                                            6.90215
# 60                                            7.03376
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], cerebro_data['2020-21 cerebrovascular disease deaths']]
cerebro_data_2020_21 = pd.DataFrame(data)
cerebro_data_2020_21 = cerebro_data_2020_21.T
cerebro_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 cerebrovascular disease deaths
# 0   05-Jan-20                 2498                                    139
# 1   12-Jan-20                 2511                                    166
# 2   19-Jan-20                 2501                                    141
# 3   26-Jan-20                 2597                                    159
# 4   02-Feb-20                 2510                                    162
# ..        ...                  ...                                    ...
# 56  31-Jan-21                 2527                                    156
# 57  07-Feb-21                 2650                                    165
# 58  14-Feb-21                 2534                                    159
# 59  21-Feb-21                 2512                                    174
# 60  28-Feb-21                 2623                                    164
#
# [61 rows x 3 columns]

# %%
cerebro_data_2020_21['2020-21 cerebrovascular disease Percentage of Total Deaths'] = (cerebro_data_2020_21['2020-21 cerebrovascular disease deaths'] / cerebro_data_2020_21['2020-21 total deaths']) * 100
cerebro_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 cerebrovascular disease deaths  \
# 0   05-Jan-20                 2498                                    139
# 1   12-Jan-20                 2511                                    166
# 2   19-Jan-20                 2501                                    141
# 3   26-Jan-20                 2597                                    159
# 4   02-Feb-20                 2510                                    162
# ..        ...                  ...                                    ...
# 56  31-Jan-21                 2527                                    156
# 57  07-Feb-21                 2650                                    165
# 58  14-Feb-21                 2534                                    159
# 59  21-Feb-21                 2512                                    174
# 60  28-Feb-21                 2623                                    164
#
#    2020-21 cerebrovascular disease Percentage of Total Deaths
# 0                                             5.56445
# 1                                             6.61091
# 2                                             5.63774
# 3                                             6.12245
# 4                                             6.45418
# ..                                                ...
# 56                                            6.17333
# 57                                            6.22642
# 58                                            6.27466
# 59                                            6.92675
# 60                                            6.25238
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], clrd_data['2015-19 avg chronic lower respiratory disease deaths']]
clrd_data_2015_19 = pd.DataFrame(data)
clrd_data_2015_19 = clrd_data_2015_19.T
clrd_data_2015_19
# Out:
#          date 2015-19 avg total deaths  \
# 0   05-Jan-20                     2498
# 1   12-Jan-20                     2490
# 2   19-Jan-20                     2465
# 3   26-Jan-20                     2446
# 4   02-Feb-20                     2451
# ..        ...                      ...
# 56  31-Jan-21                     2446
# 57  07-Feb-21                     2451
# 58  14-Feb-21                     2456
# 59  21-Feb-21                     2463
# 60  28-Feb-21                     2488
#
#    2015-19 avg chronic lower respiratory disease deaths
# 0                                                 133
# 1                                                 124
# 2                                                 118
# 3                                                 126
# 4                                                 125
# ..                                                ...
# 56                                                126
# 57                                                125
# 58                                                119
# 59                                                118
# 60                                                109
#
# [61 rows x 3 columns]

# %%
clrd_data_2015_19['2015-19 chronic lower respiratory disease Percentage of Total Deaths'] = (clrd_data_2015_19['2015-19 avg chronic lower respiratory disease deaths'] / clrd_data_2015_19['2015-19 avg total deaths']) * 100
clrd_data_2015_19
# Out:
#          date 2015-19 avg total deaths  \
# 0   05-Jan-20                     2498
# 1   12-Jan-20                     2490
# 2   19-Jan-20                     2465
# 3   26-Jan-20                     2446
# 4   02-Feb-20                     2451
# ..        ...                      ...
# 56  31-Jan-21                     2446
# 57  07-Feb-21                     2451
# 58  14-Feb-21                     2456
# 59  21-Feb-21                     2463
# 60  28-Feb-21                     2488
#
#    2015-19 avg chronic lower respiratory disease deaths  \
# 0                                                 133
# 1                                                 124
# 2                                                 118
# 3                                                 126
# 4                                                 125
# ..                                                ...
# 56                                                126
# 57                                                125
# 58                                                119
# 59                                                118
# 60                                                109
#
#    2015-19 chronic lower respiratory disease Percentage of Total Deaths
# 0                                             5.32426
# 1                                             4.97992
# 2                                             4.78702
# 3                                             5.15127
# 4                                             5.09996
# ..                                                ...
# 56                                            5.15127
# 57                                            5.09996
# 58                                            4.84528
# 59                                            4.79091
# 60                                            4.38103
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], clrd_data['2020-21 chronic lower respiratory disease deaths']]
clrd_data_2020_21 = pd.DataFrame(data)
clrd_data_2020_21 = clrd_data_2020_21.T
clrd_data_2020_21
# Out:
#          date 2020-21 total deaths  \
# 0   05-Jan-20                 2498
# 1   12-Jan-20                 2511
# 2   19-Jan-20                 2501
# 3   26-Jan-20                 2597
# 4   02-Feb-20                 2510
# ..        ...                  ...
# 56  31-Jan-21                 2527
# 57  07-Feb-21                 2650
# 58  14-Feb-21                 2534
# 59  21-Feb-21                 2512
# 60  28-Feb-21                 2623
#
#    2020-21 chronic lower respiratory disease deaths
# 0                                               127
# 1                                               145
# 2                                               120
# 3                                               132
# 4                                               134
# ..                                              ...
# 56                                              113
# 57                                              127
# 58                                              107
# 59                                              110
# 60                                              126
#
# [61 rows x 3 columns]

# %%
clrd_data_2020_21['2020-21 chronic lower respiratory disease Percentage of Total Deaths'] = (clrd_data_2020_21['2020-21 chronic lower respiratory disease deaths'] / clrd_data_2020_21['2020-21 total deaths']) * 100
clrd_data_2020_21
# Out:
#          date 2020-21 total deaths  \
# 0   05-Jan-20                 2498
# 1   12-Jan-20                 2511
# 2   19-Jan-20                 2501
# 3   26-Jan-20                 2597
# 4   02-Feb-20                 2510
# ..        ...                  ...
# 56  31-Jan-21                 2527
# 57  07-Feb-21                 2650
# 58  14-Feb-21                 2534
# 59  21-Feb-21                 2512
# 60  28-Feb-21                 2623
#
#    2020-21 chronic lower respiratory disease deaths  \
# 0                                               127
# 1                                               145
# 2                                               120
# 3                                               132
# 4                                               134
# ..                                              ...
# 56                                              113
# 57                                              127
# 58                                              107
# 59                                              110
# 60                                              126
#
#    2020-21 chronic lower respiratory disease Percentage of Total Deaths
# 0                                             5.08407
# 1                                             5.77459
# 2                                             4.79808
# 3                                             5.08279
# 4                                             5.33865
# ..                                                ...
# 56                                            4.47171
# 57                                            4.79245
# 58                                            4.22257
# 59                                            4.37898
# 60                                            4.80366
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], dementia_data['2015-19 avg dementia deaths']]
dementia_data_2015_19 = pd.DataFrame(data)
dementia_data_2015_19 = dementia_data_2015_19.T
dementia_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg dementia deaths
# 0   05-Jan-20                     2498                         232
# 1   12-Jan-20                     2490                         224
# 2   19-Jan-20                     2465                         220
# 3   26-Jan-20                     2446                         218
# 4   02-Feb-20                     2451                         220
# ..        ...                      ...                         ...
# 56  31-Jan-21                     2446                         218
# 57  07-Feb-21                     2451                         220
# 58  14-Feb-21                     2456                         224
# 59  21-Feb-21                     2463                         226
# 60  28-Feb-21                     2488                         226
#
# [61 rows x 3 columns]

# %%
dementia_data_2015_19['2015-19 dementia Percentage of Total Deaths'] = (dementia_data_2015_19['2015-19 avg dementia deaths'] / dementia_data_2015_19['2015-19 avg total deaths']) * 100
dementia_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg dementia deaths  \
# 0   05-Jan-20                     2498                         232
# 1   12-Jan-20                     2490                         224
# 2   19-Jan-20                     2465                         220
# 3   26-Jan-20                     2446                         218
# 4   02-Feb-20                     2451                         220
# ..        ...                      ...                         ...
# 56  31-Jan-21                     2446                         218
# 57  07-Feb-21                     2451                         220
# 58  14-Feb-21                     2456                         224
# 59  21-Feb-21                     2463                         226
# 60  28-Feb-21                     2488                         226
#
#    2015-19 dementia Percentage of Total Deaths
# 0                                      9.28743
# 1                                      8.99598
# 2                                      8.92495
# 3                                      8.91251
# 4                                      8.97593
# ..                                         ...
# 56                                     8.91251
# 57                                     8.97593
# 58                                     9.12052
# 59                                      9.1758
# 60                                      9.0836
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], dementia_data['2020-21 dementia deaths']]
dementia_data_2020_21 = pd.DataFrame(data)
dementia_data_2020_21 = dementia_data_2020_21.T
dementia_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 dementia deaths
# 0   05-Jan-20                 2498                     255
# 1   12-Jan-20                 2511                     265
# 2   19-Jan-20                 2501                     257
# 3   26-Jan-20                 2597                     248
# 4   02-Feb-20                 2510                     276
# ..        ...                  ...                     ...
# 56  31-Jan-21                 2527                     289
# 57  07-Feb-21                 2650                     261
# 58  14-Feb-21                 2534                     240
# 59  21-Feb-21                 2512                     257
# 60  28-Feb-21                 2623                     266
#
# [61 rows x 3 columns]

# %%
dementia_data_2020_21['2020-21 dementia Percentage of Total Deaths'] = (dementia_data_2020_21['2020-21 dementia deaths'] / dementia_data_2020_21['2020-21 total deaths']) * 100
dementia_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 dementia deaths  \
# 0   05-Jan-20                 2498                     255
# 1   12-Jan-20                 2511                     265
# 2   19-Jan-20                 2501                     257
# 3   26-Jan-20                 2597                     248
# 4   02-Feb-20                 2510                     276
# ..        ...                  ...                     ...
# 56  31-Jan-21                 2527                     289
# 57  07-Feb-21                 2650                     261
# 58  14-Feb-21                 2534                     240
# 59  21-Feb-21                 2512                     257
# 60  28-Feb-21                 2623                     266
#
#    2020-21 dementia Percentage of Total Deaths
# 0                                      10.2082
# 1                                      10.5536
# 2                                      10.2759
# 3                                      9.54948
# 4                                       10.996
# ..                                         ...
# 56                                     11.4365
# 57                                     9.84906
# 58                                     9.47119
# 59                                     10.2309
# 60                                     10.1411
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], diabetes_data['2015-19 avg diabetes deaths']]
diabetes_data_2015_19 = pd.DataFrame(data)
diabetes_data_2015_19 = diabetes_data_2015_19.T
diabetes_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg diabetes deaths
# 0   05-Jan-20                     2498                          71
# 1   12-Jan-20                     2490                          74
# 2   19-Jan-20                     2465                          83
# 3   26-Jan-20                     2446                          80
# 4   02-Feb-20                     2451                          78
# ..        ...                      ...                         ...
# 56  31-Jan-21                     2446                          80
# 57  07-Feb-21                     2451                          78
# 58  14-Feb-21                     2456                          85
# 59  21-Feb-21                     2463                          75
# 60  28-Feb-21                     2488                          77
#
# [61 rows x 3 columns]

# %%
diabetes_data_2015_19['2015-19 diabetes Percentage of Total Deaths'] = (diabetes_data_2015_19['2015-19 avg diabetes deaths'] / diabetes_data_2015_19['2015-19 avg total deaths']) * 100
diabetes_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg diabetes deaths  \
# 0   05-Jan-20                     2498                          71
# 1   12-Jan-20                     2490                          74
# 2   19-Jan-20                     2465                          83
# 3   26-Jan-20                     2446                          80
# 4   02-Feb-20                     2451                          78
# ..        ...                      ...                         ...
# 56  31-Jan-21                     2446                          80
# 57  07-Feb-21                     2451                          78
# 58  14-Feb-21                     2456                          85
# 59  21-Feb-21                     2463                          75
# 60  28-Feb-21                     2488                          77
#
#    2015-19 diabetes Percentage of Total Deaths
# 0                                      2.84227
# 1                                      2.97189
# 2                                      3.36714
# 3                                      3.27065
# 4                                      3.18237
# ..                                         ...
# 56                                     3.27065
# 57                                     3.18237
# 58                                     3.46091
# 59                                     3.04507
# 60                                     3.09486
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], diabetes_data['2020-21 diabetes deaths']]
diabetes_data_2020_21 = pd.DataFrame(data)
diabetes_data_2020_21 = diabetes_data_2020_21.T
diabetes_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 diabetes deaths
# 0   05-Jan-20                 2498                      86
# 1   12-Jan-20                 2511                      71
# 2   19-Jan-20                 2501                      71
# 3   26-Jan-20                 2597                      77
# 4   02-Feb-20                 2510                      80
# ..        ...                  ...                     ...
# 56  31-Jan-21                 2527                      61
# 57  07-Feb-21                 2650                      83
# 58  14-Feb-21                 2534                      78
# 59  21-Feb-21                 2512                      74
# 60  28-Feb-21                 2623                      60
#
# [61 rows x 3 columns]

# %%
diabetes_data_2020_21['2020-21 diabetes Percentage of Total Deaths'] = (diabetes_data_2020_21['2020-21 diabetes deaths'] / diabetes_data_2020_21['2020-21 total deaths']) * 100
diabetes_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 diabetes deaths  \
# 0   05-Jan-20                 2498                      86
# 1   12-Jan-20                 2511                      71
# 2   19-Jan-20                 2501                      71
# 3   26-Jan-20                 2597                      77
# 4   02-Feb-20                 2510                      80
# ..        ...                  ...                     ...
# 56  31-Jan-21                 2527                      61
# 57  07-Feb-21                 2650                      83
# 58  14-Feb-21                 2534                      78
# 59  21-Feb-21                 2512                      74
# 60  28-Feb-21                 2623                      60
#
#    2020-21 diabetes Percentage of Total Deaths
# 0                                      3.44275
# 1                                      2.82756
# 2                                      2.83886
# 3                                      2.96496
# 4                                      3.18725
# ..                                         ...
# 56                                     2.41393
# 57                                     3.13208
# 58                                     3.07814
# 59                                     2.94586
# 60                                     2.28746
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], heart_data['2015-19 avg heart disease deaths']]
heart_data_2015_19 = pd.DataFrame(data)
heart_data_2015_19 = heart_data_2015_19.T
heart_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg heart disease deaths
# 0   05-Jan-20                     2498                              269
# 1   12-Jan-20                     2490                              258
# 2   19-Jan-20                     2465                              272
# 3   26-Jan-20                     2446                              245
# 4   02-Feb-20                     2451                              267
# ..        ...                      ...                              ...
# 56  31-Jan-21                     2446                              245
# 57  07-Feb-21                     2451                              267
# 58  14-Feb-21                     2456                              265
# 59  21-Feb-21                     2463                              250
# 60  28-Feb-21                     2488                              255
#
# [61 rows x 3 columns]

# %%
heart_data_2015_19['2015-19 heart disease Percentage of Total Deaths'] = (heart_data_2015_19['2015-19 avg heart disease deaths'] / heart_data_2015_19['2015-19 avg total deaths']) * 100
heart_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg heart disease deaths  \
# 0   05-Jan-20                     2498                              269
# 1   12-Jan-20                     2490                              258
# 2   19-Jan-20                     2465                              272
# 3   26-Jan-20                     2446                              245
# 4   02-Feb-20                     2451                              267
# ..        ...                      ...                              ...
# 56  31-Jan-21                     2446                              245
# 57  07-Feb-21                     2451                              267
# 58  14-Feb-21                     2456                              265
# 59  21-Feb-21                     2463                              250
# 60  28-Feb-21                     2488                              255
#
#    2015-19 heart disease Percentage of Total Deaths
# 0                                           10.7686
# 1                                           10.3614
# 2                                           11.0345
# 3                                           10.0164
# 4                                           10.8935
# ..                                              ...
# 56                                          10.0164
# 57                                          10.8935
# 58                                          10.7899
# 59                                          10.1502
# 60                                          10.2492
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], heart_data['2020-21 heart disease deaths']]
heart_data_2020_21 = pd.DataFrame(data)
heart_data_2020_21 = heart_data_2020_21.T
heart_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 heart disease deaths
# 0   05-Jan-20                 2498                          215
# 1   12-Jan-20                 2511                          218
# 2   19-Jan-20                 2501                          234
# 3   26-Jan-20                 2597                          244
# 4   02-Feb-20                 2510                          235
# ..        ...                  ...                          ...
# 56  31-Jan-21                 2527                          221
# 57  07-Feb-21                 2650                          249
# 58  14-Feb-21                 2534                          250
# 59  21-Feb-21                 2512                          208
# 60  28-Feb-21                 2623                          244
#
# [61 rows x 3 columns]

# %%
heart_data_2020_21['2020-21 heart disease Percentage of Total Deaths'] = (heart_data_2020_21['2020-21 heart disease deaths'] / heart_data_2020_21['2020-21 total deaths']) * 100
heart_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 heart disease deaths  \
# 0   05-Jan-20                 2498                          215
# 1   12-Jan-20                 2511                          218
# 2   19-Jan-20                 2501                          234
# 3   26-Jan-20                 2597                          244
# 4   02-Feb-20                 2510                          235
# ..        ...                  ...                          ...
# 56  31-Jan-21                 2527                          221
# 57  07-Feb-21                 2650                          249
# 58  14-Feb-21                 2534                          250
# 59  21-Feb-21                 2512                          208
# 60  28-Feb-21                 2623                          244
#
#    2020-21 heart disease Percentage of Total Deaths
# 0                                           8.60689
# 1                                            8.6818
# 2                                           9.35626
# 3                                           9.39546
# 4                                           9.36255
# ..                                              ...
# 56                                          8.74555
# 57                                          9.39623
# 58                                          9.86582
# 59                                          8.28025
# 60                                          9.30233
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], pneumonia_data['2015-19 avg pneumonia deaths']]
pneumonia_data_2015_19 = pd.DataFrame(data)
pneumonia_data_2015_19 = pneumonia_data_2015_19.T
pneumonia_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg pneumonia deaths
# 0   05-Jan-20                     2498                           45
# 1   12-Jan-20                     2490                           42
# 2   19-Jan-20                     2465                           37
# 3   26-Jan-20                     2446                           35
# 4   02-Feb-20                     2451                           37
# ..        ...                      ...                          ...
# 56  31-Jan-21                     2446                           35
# 57  07-Feb-21                     2451                           37
# 58  14-Feb-21                     2456                           35
# 59  21-Feb-21                     2463                           43
# 60  28-Feb-21                     2488                           40
#
# [61 rows x 3 columns]

# %%
pneumonia_data_2015_19['2015-19 pneumonia Percentage of Total Deaths'] = (pneumonia_data_2015_19['2015-19 avg pneumonia deaths'] / pneumonia_data_2015_19['2015-19 avg total deaths']) * 100
pneumonia_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg pneumonia deaths  \
# 0   05-Jan-20                     2498                           45
# 1   12-Jan-20                     2490                           42
# 2   19-Jan-20                     2465                           37
# 3   26-Jan-20                     2446                           35
# 4   02-Feb-20                     2451                           37
# ..        ...                      ...                          ...
# 56  31-Jan-21                     2446                           35
# 57  07-Feb-21                     2451                           37
# 58  14-Feb-21                     2456                           35
# 59  21-Feb-21                     2463                           43
# 60  28-Feb-21                     2488                           40
#
#    2015-19 pneumonia Percentage of Total Deaths
# 0                                       1.80144
# 1                                       1.68675
# 2                                       1.50101
# 3                                       1.43091
# 4                                       1.50959
# ..                                          ...
# 56                                      1.43091
# 57                                      1.50959
# 58                                      1.42508
# 59                                      1.74584
# 60                                      1.60772
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], pneumonia_data['2020-21 pneumonia deaths']]
pneumonia_data_2020_21 = pd.DataFrame(data)
pneumonia_data_2020_21 = pneumonia_data_2020_21.T
pneumonia_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 pneumonia deaths
# 0   05-Jan-20                 2498                       42
# 1   12-Jan-20                 2511                       40
# 2   19-Jan-20                 2501                       37
# 3   26-Jan-20                 2597                       44
# 4   02-Feb-20                 2510                       31
# ..        ...                  ...                      ...
# 56  31-Jan-21                 2527                       26
# 57  07-Feb-21                 2650                       37
# 58  14-Feb-21                 2534                       27
# 59  21-Feb-21                 2512                       37
# 60  28-Feb-21                 2623                       37
#
# [61 rows x 3 columns]

# %%
pneumonia_data_2020_21['2020-21 pneumonia Percentage of Total Deaths'] = (pneumonia_data_2020_21['2020-21 pneumonia deaths'] / pneumonia_data_2020_21['2020-21 total deaths']) * 100
pneumonia_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 pneumonia deaths  \
# 0   05-Jan-20                 2498                       42
# 1   12-Jan-20                 2511                       40
# 2   19-Jan-20                 2501                       37
# 3   26-Jan-20                 2597                       44
# 4   02-Feb-20                 2510                       31
# ..        ...                  ...                      ...
# 56  31-Jan-21                 2527                       26
# 57  07-Feb-21                 2650                       37
# 58  14-Feb-21                 2534                       27
# 59  21-Feb-21                 2512                       37
# 60  28-Feb-21                 2623                       37
#
#    2020-21 pneumonia Percentage of Total Deaths
# 0                                       1.68135
# 1                                       1.59299
# 2                                       1.47941
# 3                                       1.69426
# 4                                       1.23506
# ..                                          ...
# 56                                      1.02889
# 57                                      1.39623
# 58                                      1.06551
# 59                                      1.47293
# 60                                       1.4106
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2015-19 avg total deaths'], respiratory_data['2015-19 avg respiratory disease deaths']]
respiratory_data_2015_19 = pd.DataFrame(data)
respiratory_data_2015_19 = respiratory_data_2015_19.T
respiratory_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg respiratory disease deaths
# 0   05-Jan-20                     2498                                    233
# 1   12-Jan-20                     2490                                    220
# 2   19-Jan-20                     2465                                    206
# 3   26-Jan-20                     2446                                    218
# 4   02-Feb-20                     2451                                    219
# ..        ...                      ...                                    ...
# 56  31-Jan-21                     2446                                    218
# 57  07-Feb-21                     2451                                    219
# 58  14-Feb-21                     2456                                    212
# 59  21-Feb-21                     2463                                    216
# 60  28-Feb-21                     2488                                    206
#
# [61 rows x 3 columns]

# %%
respiratory_data_2015_19['2015-19 respiratory disease Percentage of Total Deaths'] = (respiratory_data_2015_19['2015-19 avg respiratory disease deaths'] / respiratory_data_2015_19['2015-19 avg total deaths']) * 100
respiratory_data_2015_19
# Out:
#          date 2015-19 avg total deaths 2015-19 avg respiratory disease deaths  \
# 0   05-Jan-20                     2498                                    233
# 1   12-Jan-20                     2490                                    220
# 2   19-Jan-20                     2465                                    206
# 3   26-Jan-20                     2446                                    218
# 4   02-Feb-20                     2451                                    219
# ..        ...                      ...                                    ...
# 56  31-Jan-21                     2446                                    218
# 57  07-Feb-21                     2451                                    219
# 58  14-Feb-21                     2456                                    212
# 59  21-Feb-21                     2463                                    216
# 60  28-Feb-21                     2488                                    206
#
#    2015-19 respiratory disease Percentage of Total Deaths
# 0                                             9.32746
# 1                                             8.83534
# 2                                               8.357
# 3                                             8.91251
# 4                                             8.93513
# ..                                                ...
# 56                                            8.91251
# 57                                            8.93513
# 58                                            8.63192
# 59                                            8.76979
# 60                                            8.27974
#
# [61 rows x 4 columns]

# %%
data = [new_total_data['date'], new_total_data['2020-21 total deaths'], respiratory_data['2020-21 respiratory disease deaths']]
respiratory_data_2020_21 = pd.DataFrame(data)
respiratory_data_2020_21 = respiratory_data_2020_21.T
respiratory_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 respiratory disease deaths
# 0   05-Jan-20                 2498                                240
# 1   12-Jan-20                 2511                                240
# 2   19-Jan-20                 2501                                222
# 3   26-Jan-20                 2597                                242
# 4   02-Feb-20                 2510                                226
# ..        ...                  ...                                ...
# 56  31-Jan-21                 2527                                211
# 57  07-Feb-21                 2650                                231
# 58  14-Feb-21                 2534                                199
# 59  21-Feb-21                 2512                                197
# 60  28-Feb-21                 2623                                226
#
# [61 rows x 3 columns]

# %%
respiratory_data_2020_21['2020-21 respiratory disease Percentage of Total Deaths'] = (respiratory_data_2020_21['2020-21 respiratory disease deaths'] / respiratory_data_2020_21['2020-21 total deaths']) * 100
respiratory_data_2020_21
# Out:
#          date 2020-21 total deaths 2020-21 respiratory disease deaths  \
# 0   05-Jan-20                 2498                                240
# 1   12-Jan-20                 2511                                240
# 2   19-Jan-20                 2501                                222
# 3   26-Jan-20                 2597                                242
# 4   02-Feb-20                 2510                                226
# ..        ...                  ...                                ...
# 56  31-Jan-21                 2527                                211
# 57  07-Feb-21                 2650                                231
# 58  14-Feb-21                 2534                                199
# 59  21-Feb-21                 2512                                197
# 60  28-Feb-21                 2623                                226
#
#    2020-21 respiratory disease Percentage of Total Deaths
# 0                                             9.60769
# 1                                             9.55795
# 2                                             8.87645
# 3                                             9.31844
# 4                                             9.00398
# ..                                                ...
# 56                                            8.34982
# 57                                            8.71698
# 58                                             7.8532
# 59                                            7.84236
# 60                                            8.61609
#
# [61 rows x 4 columns]

# %%
data = [total_data["date"],
            total_data["COVID-19 new infections"], 
            new_total_data["2020-21 total deaths"],
            cancer_data_2015_19["2015-19 Cancer Percentage of Total Deaths"],
            cerebro_data_2015_19["2015-19 cerebrovascular disease Percentage of Total Deaths"],
            clrd_data_2015_19["2015-19 chronic lower respiratory disease Percentage of Total Deaths"],
            dementia_data_2015_19["2015-19 dementia Percentage of Total Deaths"],
            diabetes_data_2015_19["2015-19 diabetes Percentage of Total Deaths"],
            heart_data_2015_19["2015-19 heart disease Percentage of Total Deaths"], 
            pneumonia_data_2015_19["2015-19 pneumonia Percentage of Total Deaths"], 
            respiratory_data_2015_19["2015-19 respiratory disease Percentage of Total Deaths"], 
            ]
perc_Deaths_Summary2015_19 = pd.DataFrame(data).T

#round to 2 decimal places 
cols = perc_Deaths_Summary2015_19.columns
perc_Deaths_Summary2015_19[cols[1:]] = perc_Deaths_Summary2015_19[cols[1:]].apply(pd.to_numeric, errors='coerce')
perc_Deaths_Summary2015_19 = perc_Deaths_Summary2015_19.round(2)

perc_Deaths_Summary2015_19
# Out:
#          date  COVID-19 new infections  2020-21 total deaths  \
# 0   05-Jan-20                        0                  2498
# 1   12-Jan-20                        0                  2511
# 2   19-Jan-20                        0                  2501
# 3   26-Jan-20                        4                  2597
# 4   02-Feb-20                        8                  2510
# ..        ...                      ...                   ...
# 56  31-Jan-21                       44                  2527
# 57  07-Feb-21                       39                  2650
# 58  14-Feb-21                       46                  2534
# 59  21-Feb-21                       25                  2512
# 60  28-Feb-21                       42                  2623
#
#     2015-19 Cancer Percentage of Total Deaths  \
# 0                                       34.75
# 1                                       34.90
# 2                                       35.46
# 3                                       35.57
# 4                                       35.25
# ..                                        ...
# 56                                      35.57
# 57                                      35.25
# 58                                      34.93
# 59                                      34.84
# 60                                      35.85
#
#     2015-19 cerebrovascular disease Percentage of Total Deaths  \
# 0                                                7.29
# 1                                                7.15
# 2                                                6.77
# 3                                                7.20
# 4                                                6.85
# ..                                                ...
# 56                                               7.20
# 57                                               6.85
# 58                                               6.72
# 59                                               6.90
# 60                                               7.03
#
#     2015-19 chronic lower respiratory disease Percentage of Total Deaths  \
# 0                                                5.32
# 1                                                4.98
# 2                                                4.79
# 3                                                5.15
# 4                                                5.10
# ..                                                ...
# 56                                               5.15
# 57                                               5.10
# 58                                               4.85
# 59                                               4.79
# 60                                               4.38
#
#     2015-19 dementia Percentage of Total Deaths  \
# 0                                          9.29
# 1                                          9.00
# 2                                          8.92
# 3                                          8.91
# 4                                          8.98
# ..                                          ...
# 56                                         8.91
# 57                                         8.98
# 58                                         9.12
# 59                                         9.18
# 60                                         9.08
#
#     2015-19 diabetes Percentage of Total Deaths  \
# 0                                          2.84
# 1                                          2.97
# 2                                          3.37
# 3                                          3.27
# 4                                          3.18
# ..                                          ...
# 56                                         3.27
# 57                                         3.18
# 58                                         3.46
# 59                                         3.05
# 60                                         3.09
#
#     2015-19 heart disease Percentage of Total Deaths  \
# 0                                              10.77
# 1                                              10.36
# 2                                              11.03
# 3                                              10.02
# 4                                              10.89
# ..                                               ...
# 56                                             10.02
# 57                                             10.89
# 58                                             10.79
# 59                                             10.15
# 60                                             10.25
#
#     2015-19 pneumonia Percentage of Total Deaths  \
# 0                                           1.80
# 1                                           1.69
# 2                                           1.50
# 3                                           1.43
# 4                                           1.51
# ..                                           ...
# 56                                          1.43
# 57                                          1.51
# 58                                          1.43
# 59                                          1.75
# 60                                          1.61
#
#     2015-19 respiratory disease Percentage of Total Deaths
# 0                                                9.33
# 1                                                8.84
# 2                                                8.36
# 3                                                8.91
# 4                                                8.94
# ..                                                ...
# 56                                               8.91
# 57                                               8.94
# 58                                               8.63
# 59                                               8.77
# 60                                               8.28
#
# [61 rows x 11 columns]

# %%
data = [total_data["date"],
            total_data["COVID-19 new infections"], 
            new_total_data["2020-21 total deaths"],
            cancer_data_2020_21["2020-21 Cancer Percentage of Total Deaths"],
            cerebro_data_2020_21["2020-21 cerebrovascular disease Percentage of Total Deaths"],
            clrd_data_2020_21["2020-21 chronic lower respiratory disease Percentage of Total Deaths"],
            dementia_data_2020_21["2020-21 dementia Percentage of Total Deaths"],
            diabetes_data_2020_21["2020-21 diabetes Percentage of Total Deaths"],
            heart_data_2020_21["2020-21 heart disease Percentage of Total Deaths"], 
            pneumonia_data_2020_21["2020-21 pneumonia Percentage of Total Deaths"], 
            respiratory_data_2020_21["2020-21 respiratory disease Percentage of Total Deaths"], 
            ]
perc_Deaths_Summary2020_21 = pd.DataFrame(data).T

#round to 2 decimal places 
cols = perc_Deaths_Summary2020_21.columns
perc_Deaths_Summary2020_21[cols[1:]] = perc_Deaths_Summary2020_21[cols[1:]].apply(pd.to_numeric, errors='coerce')
perc_Deaths_Summary2020_21 = perc_Deaths_Summary2020_21.round(2)

perc_Deaths_Summary2020_21
# Out:
#          date  COVID-19 new infections  2020-21 total deaths  \
# 0   05-Jan-20                        0                  2498
# 1   12-Jan-20                        0                  2511
# 2   19-Jan-20                        0                  2501
# 3   26-Jan-20                        4                  2597
# 4   02-Feb-20                        8                  2510
# ..        ...                      ...                   ...
# 56  31-Jan-21                       44                  2527
# 57  07-Feb-21                       39                  2650
# 58  14-Feb-21                       46                  2534
# 59  21-Feb-21                       25                  2512
# 60  28-Feb-21                       42                  2623
#
#     2020-21 Cancer Percentage of Total Deaths  \
# 0                                       33.99
# 1                                       35.80
# 2                                       36.47
# 3                                       35.85
# 4                                       33.07
# ..                                        ...
# 56                                      35.38
# 57                                      34.94
# 58                                      36.07
# 59                                      36.11
# 60                                      36.14
#
#     2020-21 cerebrovascular disease Percentage of Total Deaths  \
# 0                                                5.56
# 1                                                6.61
# 2                                                5.64
# 3                                                6.12
# 4                                                6.45
# ..                                                ...
# 56                                               6.17
# 57                                               6.23
# 58                                               6.27
# 59                                               6.93
# 60                                               6.25
#
#     2020-21 chronic lower respiratory disease Percentage of Total Deaths  \
# 0                                                5.08
# 1                                                5.77
# 2                                                4.80
# 3                                                5.08
# 4                                                5.34
# ..                                                ...
# 56                                               4.47
# 57                                               4.79
# 58                                               4.22
# 59                                               4.38
# 60                                               4.80
#
#     2020-21 dementia Percentage of Total Deaths  \
# 0                                         10.21
# 1                                         10.55
# 2                                         10.28
# 3                                          9.55
# 4                                         11.00
# ..                                          ...
# 56                                        11.44
# 57                                         9.85
# 58                                         9.47
# 59                                        10.23
# 60                                        10.14
#
#     2020-21 diabetes Percentage of Total Deaths  \
# 0                                          3.44
# 1                                          2.83
# 2                                          2.84
# 3                                          2.96
# 4                                          3.19
# ..                                          ...
# 56                                         2.41
# 57                                         3.13
# 58                                         3.08
# 59                                         2.95
# 60                                         2.29
#
#     2020-21 heart disease Percentage of Total Deaths  \
# 0                                               8.61
# 1                                               8.68
# 2                                               9.36
# 3                                               9.40
# 4                                               9.36
# ..                                               ...
# 56                                              8.75
# 57                                              9.40
# 58                                              9.87
# 59                                              8.28
# 60                                              9.30
#
#     2020-21 pneumonia Percentage of Total Deaths  \
# 0                                           1.68
# 1                                           1.59
# 2                                           1.48
# 3                                           1.69
# 4                                           1.24
# ..                                           ...
# 56                                          1.03
# 57                                          1.40
# 58                                          1.07
# 59                                          1.47
# 60                                          1.41
#
#     2020-21 respiratory disease Percentage of Total Deaths
# 0                                                9.61
# 1                                                9.56
# 2                                                8.88
# 3                                                9.32
# 4                                                9.00
# ..                                                ...
# 56                                               8.35
# 57                                               8.72
# 58                                               7.85
# 59                                               7.84
# 60                                               8.62
#
# [61 rows x 11 columns]

# %%
###############################
## tables to upload to SQL
# new_total_data                 1
# cancer_data                    2
# cerebro_data                   3
# clrd_data                      4
# dementia_data                  5
# diabetes_data                  6
# heart_data                     7
# pneumonia_data                 8 
# respiratory_data               9 
# Deaths_Summary2015_19         10
# Deaths_Summary2020_21         11
# perc_Deaths_Summary2015_19    12
# perc_Deaths_Summary2020_21    13

# %%
#read everything into csv

new_total_data.to_csv('../Tables/total_data.csv', index=False)  
cancer_data .to_csv('../Tables/cancer_data.csv', index=False)  
cerebro_data.to_csv('../Tables/cerebro_data.csv', index=False)  
clrd_data.to_csv('../Tables/clrd_data.csv', index=False)  
dementia_data.to_csv('../Tables/dementia_data.csv', index=False)  
diabetes_data.to_csv('../Tables/diabetes_data.csv', index=False)  
heart_data.to_csv('../Tables/heart_data.csv', index=False)  
pneumonia_data.to_csv('../Tables/pneumonia_data.csv', index=False)  
respiratory_data.to_csv('../Tables/respiratory_data.csv', index=False)  
Deaths_Summary2015_19.to_csv('../Tables/Deaths_Summary2015_19.csv', index=False)  
Deaths_Summary2020_21.to_csv('../Tables/Deaths_Summary2020_21.csv', index=False)  
perc_Deaths_Summary2015_19.to_csv('../Tables/perc_Deaths_Summary2015_19.csv', index=False)  
perc_Deaths_Summary2020_21.to_csv('../Tables/perc_Deaths_Summary2020_21.csv', index=False)

# %%
#class Total(Base):
#    __tablename__ = 'total_deaths'
#    date = Column(Integer, primary_key=True)
#    avg_total_deaths_2015_19 = Column(Float)
#    total_deaths_2020_21 = Column(Float)
#    total_change = Column(Float)
#    percent_total_change = Column(Float)

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/ETL')
new_total_data.to_sql('new_total_data', engine, if_exists = 'replace')

# %%
cancer_data.to_sql('cancer_data', engine, if_exists = 'replace')

# %%
cerebro_data.to_sql('cerebro_data', engine, if_exists = 'replace')

# %%
clrd_data.to_sql('clrd_data', engine, if_exists = 'replace')

# %%
dementia_data.to_sql('dementia_data', engine, if_exists = 'replace')

# %%
diabetes_data.to_sql('diabetes_data', engine, if_exists = 'replace')

# %%
heart_data.to_sql('heart_data', engine, if_exists = 'replace')

# %%
pneumonia_data.to_sql('pneumonia_data', engine, if_exists = 'replace')

# %%
respiratory_data.to_sql('respiratory_data', engine, if_exists = 'replace')

# %%
Deaths_Summary2015_19.to_sql('Deaths_Summary2015_19', engine, if_exists = 'replace')

# %%
Deaths_Summary2020_21.to_sql('Deaths_Summary2020_21', engine, if_exists = 'replace')

# %%
perc_Deaths_Summary2015_19.to_sql('perc_Deaths_Summary2015_19', engine, if_exists = 'replace')

# %%
perc_Deaths_Summary2020_21.to_sql('respiratory_data', engine, if_exists = 'replace')
